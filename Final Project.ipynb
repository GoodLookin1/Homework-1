# %% [markdown]
# Final Project

# %% [markdown]
# Paul Astorga & Kayden Finlayson
#
# We are going to build a few models which attempt to predict whether or not an employee is granted access to a resource given data on each employee. Our data is Amazon employee access data which we retrieved from Kaggle. Let's start by importing some modules to help us build out our models, then we will load in our data and see what we can learn.

# %%
import pandas as pd
import seaborn as sns
import csv
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk
import seaborn as sns
import sqlite3
# %matplotlib inline
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier

from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %% [markdown]
# ## Load in Data

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# ## Column Name	Description

# %% [markdown]
# ### Identification
#
# - RESOURCE:	An ID for each resource
# - MGR_ID: The EMPLOYEE ID of the manager of the current EMPLOYEE ID record; an employee may have only one manager at a time

# %% [markdown]
# ### Dependent Variable
#
# - ACTION: is 1 if the resource was approved, 0 if the resource was not

# %% [markdown]
# ### Independent Variables
#
# - ROLE_ROLLUP_1:	Company role grouping category id 1 (e.g. US Engineering)
# - ROLE_ROLLUP_2:	Company role grouping category id 2 (e.g. US Retail)
# - ROLE_DEPTNAME:	Company role department description (e.g. Retail)
# - ROLE_TITLE:	Company role business title description (e.g. Senior Engineering Retail Manager)
# - ROLE_FAMILY_DESC: Company role family extended description (e.g. Retail Manager, Software Engineering)
# - ROLE_FAMILY:	Company role family description (e.g. Retail Manager)
# - ROLE_CODE:	Company role code; this code is unique to each role (e.g. Manager)

# %% [markdown]
# ## Understanding the Data

# %%
# Get the shape of the training and test sets

train_df_shape = list(df_train.shape)
train_df_shape[0] = str(train_df_shape[0]) + " Rows"
train_df_shape[1] = str(train_df_shape[1]) + " Columns"
print("Train", train_df_shape)

test_df_shape = list(df_test.shape)
test_df_shape[0] = str(test_df_shape[0]) + " Rows"
test_df_shape[1] = str(test_df_shape[1]) + " Columns"
print("Test", test_df_shape)
# Out:
# Train ['32769 Rows', '10 Columns']
# Test ['912363 Rows', '10 Columns']

# %% [markdown]
# Good, we've got a lot of data to work with in our train and almost 1 million in our test set.  That means we can be confident that at least our modeling efforts won't be underpowered.

# %%
df_train.head()
# Out:
#    ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0       1     39353   85475         117961         118300         123472
# 1       1     17183    1540         117961         118343         123125
# 2       1     36724   14457         118219         118220         117884
# 3       1     36135    5396         117961         118343         119993
# 4       1     42680    5905         117929         117930         119569
#
#    ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0      117905            117906       290919     117908
# 1      118536            118536       308574     118539
# 2      117879            267952        19721     117880
# 3      118321            240983       290919     118322
# 4      119323            123932        19793     119325

# %%
df_test.head()
# Out:
#    id  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0   1     32642    7792         118573         118574         117945
# 1   2      4696   14638         117961         118343         118514
# 2   3     22662    1760         118887         118888         120171
# 3   4     75078    7576         117961         118052         120671
# 4   5     39879   55668         117902         118041         117945
#
#    ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0      136261            128463       292795     119082
# 1      118321            289122       255851     118322
# 2      118396            255118       118398     118399
# 3      118321            117906       257051     118322
# 4      135951            134458        19776     119082

# %% [markdown]
# Taking a quick look at our training and test sets tells a few things. First the good news: every element is a number which makes this dataset literally plug and play from a modeling perspective. The bad news is that this makes it a little harder to conceptualize and understand what each element means. Some are easier to understand than others, for example there is a unique MGR_ID for each manager and unique ID for each RESOURCE.

# %% [markdown]
# Now we should check to see if we are missing any data in both our train and test sets.

# %%
df_train.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# ROLE_CODE           0
# ROLE_FAMILY         0
# ROLE_FAMILY_DESC    0
# ROLE_TITLE          0
# ROLE_DEPTNAME       0
# dtype: int64

# %%
df_test.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# ROLE_CODE           0
# ROLE_FAMILY         0
# ROLE_FAMILY_DESC    0
# ROLE_TITLE          0
# ROLE_DEPTNAME       0
# dtype: int64

# %% [markdown]
# Nice, we aren't missing any data!

# %%
cutoff = int(df_train.shape[0]/2)
x_train = df_train.loc[:(cutoff - 1), ~df_train.columns.isin(["ACTION"])]
y_train = df_train["ACTION"][:cutoff]
x_test = df_train.loc[cutoff:, ~df_train.columns.isin(["ACTION"])]
y_test = df_train["ACTION"][cutoff:]

# %%
x_train.shape
# Out:
# (16384, 9)

# %%
y_train.shape
# Out:
# (16384,)

# %%
x_test.shape
# Out:
# (16385, 9)

# %%
y_test.shape
# Out:
# (16385,)

# %% [markdown]
# ## Models

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn import metrics

Logistic = LogisticRegression()
Logistic.fit(x_train, y_train)
y_pred_train = Logistic.predict(x_train)

print("Accuracy:",metrics.accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.941650390625
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
Logistic = LogisticRegression()
Logistic.fit(x_train, y_train)
y_pred_test = Logistic.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_test))
# Out:
# Accuracy: 0.9425694232529753
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
x_train.head ()
# Out:
#    RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  ROLE_TITLE  \
# 0     39353   85475         117961         118300         123472      117905
# 1     17183    1540         117961         118343         123125      118536
# 2     36724   14457         118219         118220         117884      117879
# 3     36135    5396         117961         118343         119993      118321
# 4     42680    5905         117929         117930         119569      119323
#
#    ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0            117906       290919     117908
# 1            118536       308574     118539
# 2            267952        19721     117880
# 3            240983       290919     118322
# 4            123932        19793     119325

# %%
cutoff = int(df_train.shape[0]/2)
x_train = df_train.loc[:(cutoff - 1), ~df_train.columns.isin(["ACTION"])]
y_train = df_train["ACTION"][:cutoff]
x_test = df_train.loc[cutoff:, ~df_train.columns.isin(["ACTION"])]
y_test = df_train["ACTION"][cutoff:]

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(learning_rate=0.01, max_depth=1)
clf.fit(x_train,y_train)
y_pred_train = clf.predict(x_train)
print("Accuracy:",metrics.accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.941650390625

# %%
clf = GradientBoostingClassifier(learning_rate=0.01, max_depth=1)
clf.fit(x_train,y_train)
y_pred_test = clf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_test))
# Out:
# Accuracy: 0.9425694232529753

# %%
cutoff = int(df_train.shape[0]/2)
x_train = df_train.loc[:(cutoff - 1), ~df_train.columns.isin(["ACTION"])]
y_train = df_train["ACTION"][:cutoff]
x_test = df_train.loc[cutoff:, ~df_train.columns.isin(["ACTION"])]
y_test = df_train["ACTION"][cutoff:]

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10, max_depth=5)
clf.fit(x_train,y_train)
y_pred_train = clf.predict(x_train)
print("Accuracy:",metrics.accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.9422607421875

# %%
clf = RandomForestClassifier(n_estimators=10, max_depth=5)
clf.fit(x_train,y_train)
y_pred_test = clf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_test))
# Out:
# Accuracy: 0.9425083918217882

# %%
x_train = df_train.loc[:, ~df_train.columns.isin(["ACTION"])]
y_train = df_train["ACTION"]
x_test = df_test.loc[:, ~df_test.columns.isin(["id"])]
y_test = df_train["ACTION"]

# %%
clf = RandomForestClassifier(n_estimators=10, max_depth=5)
clf.fit(x_train,y_train)
y_pred_train = clf.predict(x_train)
print("Accuracy:",metrics.accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy: 0.9422319875492081

# %%
x_train["ACT"] = y_train
x_train["PRED"] = y_pred_train

# %%
x_train.head()
# Out:
#    RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME
totals = pd.DataFrame(totals).reset_index()
totals = pd.merge(totals, value_counts, "left", left_on = "index", right_on = "index")
totals["Proportion"] = totals["RESOURCE_y"]/totals["RESOURCE_x"]
totals.sort_values("Proportion", ascending=False)
# Out:
#        index  RESOURCE_x  RESOURCE_y  Proportion
# 7475   40472           1         1.0         1.0
# 4856  106868           1         1.0         1.0
# 4669  114822           1         1.0         1.0
# 4686   44884           1         1.0         1.0
# 4694   26381           1         1.0         1.0
# 4703   16038           1         1.0         1.0
# 4704   80729           1         1.0         1.0
# 4710   82090           1         1.0         1.0
# 4711   80569           1         1.0         1.0
# 4737   16282           1         1.0         1.0
# 4769   25747           1         1.0         1.0
# 4778   80856           1         1.0         1.0
# 4796   42123           1         1.0         1.0
# 4810   92397           1         1.0         1.0
# 4818   16488           1         1.0         1.0
# 4823   38963           1         1.0         1.0
# 4839   80455           1         1.0         1.0
# 4645   77976           1         1.0         1.0
# 4627   31025           1         1.0         1.0
# 4626   35347           1         1.0         1.0
# 4521   81510           1         1.0         1.0
# 4464   96520           1         1.0         1.0
# 4467   43250           1         1.0         1.0
# 4485   74776           1         1.0         1.0
# 4493   36752           1         1.0         1.0
# 4499   17782           1         1.0         1.0
# 4515   91181           1         1.0         1.0
# 4537   73154           1         1.0         1.0
# 4622   16630           1         1.0         1.0
# 4547   27692           1         1.0         1.0
# ...      ...         ...         ...         ...
# 7488   35046           1         NaN         NaN
# 7489   92378           1         NaN         NaN
# 7490  100413           1         NaN         NaN
# 7491   79728           1         NaN         NaN
# 7492   79792           1         NaN         NaN
# 7493   36894           1         NaN         NaN
# 7494   28635           1         NaN         NaN
# 7495   59370           1         NaN         NaN
# 7496   45057           1         NaN         NaN
# 7497   30629           1         NaN         NaN
# 7498   18462           1         NaN         NaN
# 7499   38809           1         NaN         NaN
# 7500   77905           1         NaN         NaN
# 7501   42879           1         NaN         NaN
# 7502   75631           1         NaN         NaN
# 7503   39012           1         NaN         NaN
# 7504   30565           1         NaN         NaN
# 7505   18275           1         NaN         NaN
# 7506   79693           1         NaN         NaN
# 7507   97530           1         NaN         NaN
# 7508   28793           1         NaN         NaN
# 7509   18243           1         NaN         NaN
# 7510   20290           1         NaN         NaN
# 7511   26407           1         NaN         NaN
# 7512   43202           1         NaN         NaN
# 7513   35014           1         NaN         NaN
# 7514   75535           1         NaN         NaN
# 7515   30936           1         NaN         NaN
# 7516   89856           1         NaN         NaN
# 7517   16376           1         NaN         NaN
#
# [7518 rows x 4 columns]

# %%
totals.sort_values(by=['Proportion'])
# Out:
#        index  RESOURCE_x  RESOURCE_y  Proportion
# 0       4675         839         3.0    0.003576
# 3      75078         409         4.0    0.009780
# 32     34950          91         1.0    0.010989
# 34     73756          87         1.0    0.011494
# 9      17308         239         3.0    0.012552
# 18     79121         157         2.0    0.012739
# 44     73815          73         1.0    0.013699
# 4       3853         404         6.0    0.014851
# 56     40867          62         1.0    0.016129
# 6      75834         299         5.0    0.016722
# 57     16191          58         1.0    0.017241
# 59      7678          57         1.0    0.017544
# 61      3130          56         1.0    0.017857
# 15     23921         167         3.0    0.017964
# 65      1937          52         1.0    0.019231
# 69     37260          50         1.0    0.020000
# 72       971          48         1.0    0.020833
# 10      1020         236         5.0    0.021186
# 30       972          92         2.0    0.021739
# 19     28149         137         3.0    0.021898
# 76     41594          45         1.0    0.022222
# 33     27124          88         2.0    0.022727
# 85     37651          42         1.0    0.023810
# 35     33248          84         2.0    0.023810
# 36     17249          83         2.0    0.024096
# 90     41758          40         1.0    0.025000
# 87     16443          40         1.0    0.025000
# 94     15022          38         1.0    0.026316
# 101    35498          36         1.0    0.027778
# 46     28294          68         2.0    0.029412
# ...      ...         ...         ...         ...
# 7488   35046           1         NaN         NaN
# 7489   92378           1         NaN         NaN
# 7490  100413           1         NaN         NaN
# 7491   79728           1         NaN         NaN
# 7492   79792           1         NaN         NaN
# 7493   36894           1         NaN         NaN
# 7494   28635           1         NaN         NaN
# 7495   59370           1         NaN         NaN
# 7496   45057           1         NaN         NaN
# 7497   30629           1         NaN         NaN
# 7498   18462           1         NaN         NaN
# 7499   38809           1         NaN         NaN
# 7500   77905           1         NaN         NaN
# 7501   42879           1         NaN         NaN
# 7502   75631           1         NaN         NaN
# 7503   39012           1         NaN         NaN
# 7504   30565           1         NaN         NaN
# 7505   18275           1         NaN         NaN
# 7506   79693           1         NaN         NaN
# 7507   97530           1         NaN         NaN
# 7508   28793           1         NaN         NaN
# 7509   18243           1         NaN         NaN
# 7510   20290           1         NaN         NaN
# 7511   26407           1         NaN         NaN
# 7512   43202           1         NaN         NaN
# 7513   35014           1         NaN         NaN
# 7514   75535           1         NaN         NaN
# 7515   30936           1         NaN         NaN
# 7516   89856           1         NaN         NaN
# 7517   16376           1         NaN         NaN
#
# [7518 rows x 4 columns]

# %%
totals.to_sql('totals_database', con=engine)

# %%
engine.execute("SELECT * FROM totals_database WHERE RESOURCE_x >= 10 ORDER BY Proportion DESC").fetchall()
# Out:
# [(98, 27416, 37, 18.0, 0.4864864864864865),
#  (439, 20287, 11, 5.0, 0.45454545454545453),
#  (28, 20897, 104, 42.0, 0.40384615384615385),
#  (228, 75216, 19, 6.0, 0.3157894736842105),
#  (359, 20231, 13, 4.0, 0.3076923076923077),
#  (455, 33233, 10, 3.0, 0.3),
#  (472, 39631, 10, 3.0, 0.3),
#  (112, 20222, 33, 9.0, 0.2727272727272727),
#  (418, 33229, 11, 3.0, 0.2727272727272727),
#  (421, 38205, 11, 3.0, 0.2727272727272727),
#  (425, 44655, 11, 3.0, 0.2727272727272727),
#  (448, 80501, 11, 3.0, 0.2727272727272727),
#  (226, 20284, 19, 5.0, 0.2631578947368421),
#  (139, 43877, 28, 7.0, 0.25),
#  (378, 33239, 12, 3.0, 0.25),
#  (381, 19751, 12, 3.0, 0.25),
#  (390, 31183, 12, 3.0, 0.25),
#  (154, 77300, 25, 6.0, 0.24),
#  (206, 38124, 21, 5.0, 0.23809523809523808),
#  (275, 79168, 17, 4.0, 0.23529411764705882),
#  (479, 2925, 10, None, None),
#  (480, 40531, 10, None, None),
#  (482, 33323, 10, None, None),
#  (484, 74593, 10, None, None),
#  (485, 78360, 10, None, None),
#  (486, 30839, 10, None, None),
#  (487, 75443, 10, None, None),
#  (488, 29693, 10, None, None),
#  (489, 30932, 10, None, None),
#  (490, 79228, 10, None, None),
#  (493, 35499, 10, None, None),
#  (494, 41234, 10, None, None),
#  (495, 39339, 10, None, None),
#  (497, 38119, 10, None, None),
#  (499, 41643, 10, None, None),
#  (500, 28472, 10, None, None),
#  (501, 78518, 10, None, None),
#  (502, 34871, 10, None, None),
#  (503, 6720, 10, None, None),
#  (504, 25677, 10, None, None),
#  (505, 18381, 10, None, None),
#  (507, 79323, 10, None, None),
#  (508, 18229, 10, None, None)]

# %% [markdown]
# This shows the resources that performed the worst with more than 10 observations

# %%
engine.execute("SELECT COUNT(RESOURCE_X) FROM totals_database WHERE RESOURCE_x = RESOURCE_y").fetchall()
# Out:
# [(292,)]

# %% [markdown]
# This is the number of times that the model was 100% incorrect in assignments

# %%
engine.execute("SELECT COUNT(RESOURCE_x) FROM totals_database WHERE RESOURCE_x = 1").fetchall()
# Out:
# [(3766,)]

# %% [markdown]
# This is the total number of distinct resources with only one observation

# %%
engine.execute("SELECT COUNT(RESOURCE_x) FROM totals_database WHERE RESOURCE_x = 1 AND RESOURCE_y = 1").fetchall()
# Out:
# [(268,)]

# %% [markdown]
# This is the number of times that the distinct resources with only one observation was wrong

# %%
engine.execute("SELECT * FROM totals_database WHERE Proportion > 0.45 AND RESOURCE_x < 30 AND RESOURCE_x > 5").fetchall()
# Out:
# [(439, 20287, 11, 5.0, 0.45454545454545453),
#  (614, 44976, 8, 7.0, 0.875),
#  (684, 21751, 7, 7.0, 1.0),
#  (890, 22956, 6, 5.0, 0.8333333333333334),
#  (898, 20218, 6, 3.0, 0.5)]

# %%
engine.execute("SELECT COUNT(RESOURCE_x) FROM totals_database WHERE RESOURCE_x = 1").fetchall()
# Out:
# [(3766,)]

# %% [markdown]
# prop_totalwrong = 267/1888
# print(prop_totalwrong)

# %%
unique_x_train = x_train["RESOURCE"].unique()
print(unique_x_train)
# Out:
# [39353 17183 36724 ... 32529 16354 32147]

# %%
x_train.head ()
# Out:
#    RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  ROLE_TITLE  \
# 0     39353   85475         117961         118300         123472      117905
# 1     17183    1540         117961         118343         123125      118536
# 2     36724   14457         118219         118220         117884      117879
# 3     36135    5396         117961         118343         119993      118321
# 4     42680    5905         117929         117930         119569      119323
#
#    ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE  ACT  PRED
# 0            117906       290919     117908    1     1
# 1            118536       308574     118539    1     1
# 2            267952        19721     117880    1     1
# 3            240983       290919     118322    1     1
# 4            123932        19793     119325    1     1

# %%
x_train[x_train["ACT"] != x_train["PRED"]]["ACT"].value_counts()
# Out:
# 0    1893
# Name: ACT, dtype: int64

# %%
x_train[x_train["ACT"] != x_train["PRED"]]
# Out:
#        RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
#
# 289        120357            201020       118424     120359    0     1
# 318        118318            168365       118205     118319    0     1
# 319        122989            131688       119006     122991    0     1
# 329        120313            157234       118424     120315    0     1
# 345        126684            126684       292795     126685    0     1
# 346        118777            279443       308574     118779    0     1
# 399        120344            311360       118424     120346    0     1
# 400        118841            240982       118643     118843    0     1
# 402        117905            240983       290919     117908    0     1
# 425        118995            118806       292795     118997    0     1
# 442        118777            279443       308574     118779    0     1
# ...           ...               ...          ...        ...  ...   ...
# 32227      118321            117906       290919     118322    0     1
# 32228      118318            168365       118205     118319    0     1
# 32236      118636            130218       118638     118639    0     1
# 32237      117885            117913       117887     117888    0     1
# 32264      130606            124426       118474     130607    0     1
# 32299      120647            311441       118398     120649    0     1
# 32310      118321            118448       290919     118322    0     1
# 32314      118043            118043       270488     118046    0     1
# 32342      117879            117897        19721     117880    0     1
# 32355      118321            240983       290919     118322    0     1
# 32374      118321            117906       290919     118322    0     1
# 32380      118321            117906       290919     118322    0     1
# 32404      117905            117906       290919     117908    0     1
# 32406      117879            117886        19721     117880    0     1
# 32454      117885            117913       117887     117888    0     1
# 32456      120647            311441       118398     120649    0     1
# 32485      118777            279443       308574     118779    0     1
# 32494      118568            118568        19721     118570    0     1
# 32495      118054            240326       117887     118055    0     1
# 32513      117946            125711       292795     117948    0     1
# 32525      118259            133680       290919     118261    0     1
# 32568      118636            215667       118638     118639    0     1
# 32570      118568            125652        19721     118570    0     1
# 32575      118451            270976       118453     118454    0     1
# 32604      280788            193644       292795     119082    0     1
# 32645      117946            144221       292795     117948    0     1
# 32661      120357            125779       118424     120359    0     1
# 32681      118321            117906       290919     118322    0     1
# 32707      118568            118568        19721     118570    0     1
# 32713      118321            117906       290919     118322    0     1
#
# [1893 rows x 11 columns]

# %%
x_train = df_train.loc[:, ~df_train.columns.isin(["ACTION"])]
y_train = df_train["ACTION"]
x_test = df_test.loc[:, ~df_test.columns.isin(["id"])]
y_test = df_train["ACTION"]

# %%
df_test.head()
# Out:
#    id  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0   1     32642    7792         118573         118574         117945
# 1   2      4696   14638         117961         118343         118514
# 2   3     22662    1760         118887         118888         120171
# 3   4     75078    7576         117961         118052         120671
# 4   5     39879   55668         117902         118041         117945
#
#    ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0      136261            128463       292795     119082
# 1      118321            289122       255851     118322
# 2      118396            255118       118398     118399
# 3      118321            117906       257051     118322
# 4      135951            134458        19776     119082

# %%
clf = RandomForestClassifier(n_estimators=10, max_depth=5)
clf.fit(x_train,y_train)
y_pred_test = clf.predict(x_test)

# %%
ID = df_test["id"]
#ID = pd.DataFrame(ID).reset_index()
ID = pd.DataFrame(ID)

# %%
ACTION = pd.DataFrame(y_pred_test)

# %%
from sklearn.feature_selection import SelectKBest,f_classif
from sklearn.feature_selection import chi2
selector = SelectKBest(chi2, k=6)
X_new=selector.fit_transform(x_train, y_train)
mask = selector.get_support(indices=True)
colname = x_train.columns[mask]
colname
# Out:
# Index(['MGR_ID', 'ROLE_ROLLUP_1', 'ROLE_TITLE', 'ROLE_FAMILY_DESC',
#        'ROLE_FAMILY', 'ROLE_CODE'],
#       dtype='object')
